# %%
import pandas as pd 

print("Hello World")
xlsx_file = "Cards Against Humanity.xlsx"
xlFile = pd.ExcelFile(xlsx_file)
raw_df = pd.read_excel(xlFile, sheetname="CAH Main Deck")
display(all_cards_df[3:])
# Out:
# Hello World
#                            http://cardsagainsthumanity.com/      Unnamed: 1  \
# NaN                                                     NaN             NaN
# \n                                                  Edition             NaN
# Set                       Cards Against Humanity: Main Deck         Special
# NaN                                                     NaN             NaN
# Prompt                            ______ + ______ = ______.  DRAW 2, PICK 3
# Prompt     ______ is a slippery slope that leads to ______.          PICK 2
# Prompt    ______ would be woefully incomplete without __...          PICK 2
# Prompt                       ______: good to the last drop.             NaN
# Prompt                 ______: kid tested, mother approved.             NaN
# Prompt                 ______: kid-tested, mother-approved.             NaN
# Prompt            ______: Once you pop, the fun don't stop!             NaN
# Prompt                               ______? Jim'll fix it!             NaN
# Prompt                     ______? There's an app for that.             NaN
# Prompt                                   ______? Yeah, nah.             NaN
# Prompt    ______. Awesome in theory, kind of a mess in p...             NaN
# Prompt                  ______. Betcha can't have just one!             NaN
# Prompt                              ______. High five, bro.             NaN
# Prompt                                 ______. It's a trap!             NaN
# Prompt                           ______. That was so metal.             NaN
# Prompt                    ______. That's how I want to die.             NaN
# Prompt               ______. That's why mums go to Iceland.             NaN
# Prompt    ★✰✰✰✰ Do NOT go here! Found _____ in my Kung P...             NaN
# Prompt                  50% of all marriages end in ______.             NaN
# Prompt    A recent laboratory study shows that undergrad...             NaN
# Prompt    A remarkable new study has shown that chimps h...             NaN
# Prompt    A romantic candlelit dinner would be incomplet...             NaN
# Prompt    A romantic, candlelit dinner would be incomple...             NaN
# Prompt    A successful job interview begins with a firm ...             NaN
# Prompt         ABC presents: "______: The Story of ______."          PICK 2
# Prompt    After eight years in the White House, how is O...             NaN
# ...                                                     ...             ...
# Response                                       Jimmy Savile             NaN
# Response                Just touching David Beckham’s hair.             NaN
# Response    Leaked footage of Kate Middleton’s colonoscopy.             NaN
# Response                                  Madeleine McCann.             NaN
# Response  Maureen of Blackpool, Reader’s Wife of the Yea...             NaN
# Response                                     Millwall fans.             NaN
# Response                                  Mining accidents.             NaN
# Response           One Direction’s supple, hairless bodies.             NaN
# Response     Pronouncing the names of northern Welsh towns.             NaN
# Response                 Queen Elizabeth’s immaculate anus.             NaN
# Response                           Ripping off the Beatles.             NaN
# Response  Rubbing Boris Johnson’s belly until he falls a...             NaN
# Response                         Scalping the Milkybar Kid.             NaN
# Response                                          Scousers.             NaN
# Response         Shitting out a perfect Cumberland sausage.             NaN
# Response       Slapping a biscuit out of an orphan’s mouth.             NaN
# Response                                         Spaniards.             NaN
# Response                                   The Black Death.             NaN
# Response                                  The bloody Welsh.             NaN
# Response                 The entire cast of Downtown Abbey.             NaN
# Response                                        The French.             NaN
# Response                         The Hillsborough Disaster.             NaN
# Response                                 The Honey Monster.             NaN
# Response                                         The North.             NaN
# Response           The petty troubles of the landed gentry.             NaN
# Response                                          The Stig.             NaN
# Response       The sudden appearance of the Go Compare man.             NaN
# Response                   The way James Bond treats women.             NaN
# Response                                            Tories.             NaN
# Response                                       Trench foot.             NaN
#
#            Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# NaN               NaN        NaN        NaN        NaN        NaN        NaN
# \n                 US         US         US         US         US         US
# Set       KICKSTARTER       v1.0       v1.1       v1.2       v1.3       v1.4
# NaN               NaN        NaN        NaN        NaN        NaN        NaN
# Prompt             KS       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt             KS       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt             KS       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt             KS        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt             KS       v1.0       v1.1       v1.2        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt             KS       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt            NaN       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt             KS       v1.0        NaN       v1.2       v1.3       v1.4
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt             KS        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN       v1.0       v1.1       v1.2       v1.3       v1.4
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# Prompt            NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
# Response          NaN        NaN        NaN        NaN        NaN        NaN
#
#          Unnamed: 8 Unnamed: 9     ...     Unnamed: 15 Unnamed: 16  \
# NaN             NaN        NaN     ...             NaN         NaN
# \n               US         UK     ...              CA          UK
# Set            v1.5       v1.5     ...            v1.7        v1.7
# NaN             NaN        NaN     ...             NaN         NaN
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt          NaN       v1.5     ...             NaN        v1.7
# Prompt          NaN       v1.5     ...             NaN        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt         v1.5        NaN     ...            v1.7         NaN
# Prompt         v1.5        NaN     ...            v1.7         NaN
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt          NaN        NaN     ...            v1.7        v1.7
# Prompt         v1.5       v1.5     ...             NaN         NaN
# Prompt          NaN       v1.5     ...             NaN        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...            v1.7        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt         v1.5       v1.5     ...            v1.7        v1.7
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# Prompt          NaN        NaN     ...             NaN         NaN
# ...             ...        ...     ...             ...         ...
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
# Response        NaN        NaN     ...             NaN         NaN
#
#          Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# NaN              NaN         NaN         NaN         NaN         NaN
# \n                AU          CA          US          CA          UK
# Set             v1.7       v1.7a        v2.0        v2.0        v2.0
# NaN              NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7       v1.7a         NaN         NaN         NaN
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt           NaN         NaN         NaN         NaN        v2.0
# Prompt           NaN         NaN         NaN         NaN        v2.0
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt           NaN         NaN         NaN         NaN        v2.0
# Prompt           NaN         NaN        v2.0        v2.0         NaN
# Prompt           NaN         NaN        v2.0        v2.0        v2.0
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7       v1.7a        v2.0        v2.0        v2.0
# Prompt           NaN         NaN         NaN         NaN         NaN
# Prompt          v1.7         NaN         NaN         NaN         NaN
# Prompt           NaN         NaN        v2.0         NaN         NaN
# ...              ...         ...         ...         ...         ...
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
# Response         NaN         NaN         NaN         NaN         NaN
#
#          Unnamed: 22 Unnamed: 23 Unnamed: 24
# NaN              NaN         NaN         NaN
# \n                AU        INTL         NaN
# Set             v2.0        v2.0         NaN
# NaN              NaN         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN        v2.0         NaN
# Prompt           NaN         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN        v2.0         NaN
# Prompt          v2.0         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt          v2.0        v2.0         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt           NaN         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN        v2.0         NaN
# Prompt           NaN         NaN         NaN
# Prompt          v2.0        v2.0         NaN
# Prompt           NaN        v2.0         NaN
# Prompt          v2.0         NaN         NaN
# Prompt           NaN         NaN         NaN
# ...              ...         ...         ...
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
# Response         NaN         NaN         NaN
#
# [1691 rows x 25 columns]
